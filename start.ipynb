# %%
import import_ipynb
import App
# Out:
# importing Jupyter notebook from App.ipynb
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sridh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2023-08-08 11:29:28.391
# ...
#   command:
#
#     streamlit run c:\Users\sridh\.conda\envs\resparse\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# !jupyter nbconvert --to python App.ipynb
# Out:
# [NbConvertApp] Converting notebook App.ipynb to python
# [NbConvertApp] Writing 12880 bytes to App.py

# %%
# !streamlit run App.py
# Out:
# ^C
